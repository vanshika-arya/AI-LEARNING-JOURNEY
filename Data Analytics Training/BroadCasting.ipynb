# %%
import numpy as np
a=np.array([0,1,2])
print(a.shape)
# Out:
# (3,)

# %%
#Broadcasting
#shape mismatch ho agr do aaray ki broadcasting copy banega or dono ka size equal kar dega...taki operation perform o sake
import numpy as np
a=np.tile(np.arange(0,40,10),(3,1)) #dumy data , shape match , multiple data arrange/repeat/duplicate karne ke liye tile use hoga
print(a)
a=a.T
print(a)

b=np.array([0,1,2])
a+b
# Out:
# [[ 0 10 20 30]
#  [ 0 10 20 30]
#  [ 0 10 20 30]]
# [[ 0  0  0]
#  [10 10 10]
#  [20 20 20]
#  [30 30 30]]
# array([[ 0,  1,  2],
#        [10, 11, 12],
#        [20, 21, 22],
#        [30, 31, 32]])

# %%
import numpy as np
a=np.arange(0,40,10)
a.shape
#to add anew column
a=a[:,np.newaxis] #np.newaxis se shape change hoga  --> shape change kyu karna hai...data set me kam karte waqt agr data input field nhi ho rha hai to hum reshape karte hain...ml model banane me
a.shape

b=np.array([0,1,2])
a+b
# Out:
# array([[ 0,  1,  2],
#        [10, 11, 12],
#        [20, 21, 22],
#        [30, 31, 32]])

# %%
import numpy as np
c=np.array([[1,2,3],[4,5,6]])
c.ravel() #ye koi copy creat nhi kar rha hai...sirf view dega ki isne flat kiya hai means 2d ko 1d me convert nhi kiya sirf waisa dikhaya hai
# c.T.ravel() #covert 2d array to 1d array---> return a contiguous flattend array. A 1-D array
c.shape
c
d= c.ravel()
d
print(d.reshape(2,3))
print(d.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (6,)

# %%
c[0,0]=100
d
# Out:
# array([100,   2,   3,   4,   5,   6])

# %%
a=np.zeros((2,3))
b=a.T.reshape(3*2) #may also return a copy-->reshape kabhi kabhi copy return karta hai
b[0]=50
a
b
# Out:
# array([50.,  0.,  0.,  0.,  0.,  0.])

# %%
#adding a dimension
a=np.array([1,2,3,4,5])
a
a[:, np.newaxis]
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a[:, np.newaxis]
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a=np.arange(4*3*2).reshape(4, 3,2) #reshape use---> jab bhi data fit na ho input mee....to uske liye hum reshape ka use karte hain
a
a[0,2,1]
# a.shape
# Out:
# np.int64(5)

# %%
a[0,2,1]
# Out:
# np.int64(5)

# %%
#RESIZING
a=np.arange(4)
a.resize((8,)) 
a
# Out:
# array([0, 1, 2, 3, 0, 0, 0, 0])

# %%
#it must not be refer to somewhere else:
b=a
a.resize((4,)) #resize bhi view create karta hai....copy nhi banata hai
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 #it must not be refer to somewhere else:
#       2 b=a
# ----> 3 a.resize((4,))
#       4 a
#
# ValueError: cannot resize an array that references or is referenced
# by another array in this way.
# Use the np.resize function or refcheck=False

# %%
#sorting data
a=np.array([[5,4,6],[2,3,2]])
b=np.sort(a,axis=1)
b
# Out:
# array([[4, 5, 6],
#        [2, 2, 3]])

# %%
#in place sort
a.sort(axis=1)
a
# Out:
# array([[4, 5, 6],
#        [2, 2, 3]])

# %%
a=np.array([4,3,2,1])
b=npargsort(a)

a[j]
